# %%
import pandas as pd
import numpy as np
import math
from sklearn.model_selection import train_test_split
from sklearn.ensemble import RandomForestRegressor
from sklearn.metrics import mean_squared_error, r2_score

# %%
import utils.data_preprocessing as dp

# %% [markdown]
# # データの読み込み

# %%
train = pd.read_csv("../data/train.csv")
test = pd.read_csv("../data/test.csv")

# %%
train
# Out:
#           id         region  year manufacturer  condition    cylinders fuel  \
# 0          0      nashville  1949          bmw  excellent  6 cylinders  gas
# 1          1  state college  2013       toyota       fair  8 cylinders  gas
# 2          2        wichita  1998         ford       good  6 cylinders  gas
# 3          3         albany  2014         ford  excellent  4 cylinders  gas
# 4          4        redding  2005         ford  excellent  6 cylinders  gas
# ...      ...            ...   ...          ...        ...          ...  ...
# 27527  27527   williamsport  2008         ford       good  6 cylinders  gas
# 27528  27528          tulsa  2007         ford  excellent  8 cylinders  gas
# 27529  27529      rochester  2019         jeep   like new  6 cylinders  gas
# 27530  27530      rochester  2007         jeep  excellent  6 cylinders  gas
# 27531  27531  orange county  2009    chevrolet  excellent  8 cylinders  gas
#
#        odometer title_status transmission drive       size         type  \
# 0        115148        clean       manual   rwd   mid-size  convertible
# 1        172038        clean    automatic   rwd  full-size        sedan
# 2        152492        clean    automatic   fwd  full-size          SUV
# 3        104118        clean       manual   fwd   mid-size          SUV
# 4        144554        clean       manual   fwd   mid-size        sedan
# ...         ...          ...          ...   ...        ...          ...
# 27527     26660        clean    automatic   rwd    compact        truck
# 27528    108072        clean    automatic   rwd  full-size       pickup
# 27529    139908        clean    automatic   4wd   mid-size          SUV
# 27530    112326        clean    automatic   4wd   mid-size        sedan
# 27531     91813      rebuilt    automatic   rwd  full-size          van
#
#       paint_color state  price
# 0          orange   NaN  27587
# 1          silver    pa   4724
# 2          silver    ks  10931
# 3            blue    ny  16553
# 4             red    ca   5158
# ...           ...   ...    ...
# 27527       black    pa  32212
# 27528       black   NaN   5400
# 27529       white    ny  22227
# 27530       white    ny   3054
# 27531       white    ca  20801
#
# [27532 rows x 16 columns]

# %%
train["manufacturer"].value_counts()
# Out:
# ford             6166
# chevrolet        3339
# bmw              2736
# toyota           1570
# honda            1526
#                  ...
# SΑTURN              1
# ＤＯＤＧＥ               1
# ｉｎｆｉｎｉｔｉ            1
# ｍｅｒｃｅｄｅｓ－ｂｅｎｚ       1
# ᴄhrysler            1
# Name: manufacturer, Length: 125, dtype: int64

# %% [markdown]
# # 定数

# %%
area_mapping = {
    # trainデータ
    'SF bay area': 'California',
    'ashtabula': 'Ohio',
    'brainerd': 'Minnesota',
    'brownsville': 'Texas',
    'columbia': 'South Carolina',
    'columbia / jeff city': 'Missouri',
    'daytona beach': 'Florida',
    'dubuque': 'Iowa',
    'el paso': 'Texas',
    'flagstaff / sedona': 'Arizona',
    'florence': 'South Carolina',
    'florida keys': 'Florida',
    'galveston': 'Texas',
    'grand forks': 'North Dakota',
    'grand rapids': 'Michigan',
    'great falls': 'Montana',
    'heartland florida': 'Florida',
    'imperial county': 'California',
    'joplin': 'Missouri',
    'kalispell': 'Montana',
    'lakeland': 'Florida',
    'las vegas': 'Nevada',
    'lawton': 'Oklahoma',
    'long island': 'New York',
    'manhattan': 'New York',
    'merced': 'California',
    'minneapolis / st paul': 'Minnesota',
    'morgantown': 'West Virginia',
    'moses lake': 'Washington',
    'nashville': 'Tennessee',
    'northeast SD': 'South Dakota',
    'northwest KS': 'Kansas',
    'panama city': 'Florida',
    'pittsburgh': 'Pennsylvania',
    'poconos': 'Pennsylvania',
    'pullman / moscow': 'Washington',
    'raleigh / durham / CH': 'North Carolina',
    'rockford': 'Illinois',
    'salem': 'Oregon',
    'san antonio': 'Texas',
    'san diego': 'California',
    'savannah / hinesville': 'Georgia',
    'southern WV': 'West Virginia',
    'southwest VA': 'Virginia',
    'spokane / coeur d\'alene': 'Washington',
    'tallahassee': 'Florida',
    'tucson': 'Arizona',
    'utica-rome-oneida': 'New York',
    'valdosta': 'Georgia',
    'vermont': 'Vermont',
    'waterloo / cedar falls': 'Iowa',
    'watertown': 'New York',
    'western KY': 'Kentucky',
    'yuba-sutter': 'California',
    'yuma': 'Arizona',
    #  testデータ
    'birmingham': 'Alabama',
    'central michigan': 'Michigan',
    'charleston': 'South Carolina',
    'cleveland': 'Ohio',
    'east oregon': 'Oregon',
    'eastern NC': 'North Carolina',
    'glens falls': 'New York',
    'hanford-corcoran': 'California',
    'huntsville / decatur': 'Alabama',
    'jersey shore': 'New Jersey',
    'lafayette': 'Louisiana',
    'muskegon': 'Michigan',
    'ocala': 'Florida',
    'prescott': 'Arizona',
    'rochester': 'New York',
    'siskiyou county': 'California',
    'texarkana': 'Texas',
    'waco': 'Texas',
    'western slope': 'Colorado',
    'wyoming': 'Wyoming'
}

# %% [markdown]
# # 前処理

# %%
# manufacturer
train = dp.preprocess_manufacturer(train)

# %%
# year
train = dp.fix_year_column(train)

# %%
#odometer（負を正に転換）
train["odometer"] = (train["odometer"]**2)**0.5

# %%
# size
train = dp.normalize_size_column(train)

# %%
# state
dp.fill_missing_state(train, area_mapping)

# %%
# fuel, title_status, type（現状、最頻値で埋めている）
# TODO 最頻値の他に良い埋め方はないか
dp.fillna_with_mode(train, ['fuel', 'title_status', 'type'])

# %%
train.isnull().sum()
# Out:
# id              0
# region          0
# year            0
# manufacturer    0
# condition       0
# cylinders       0
# fuel            0
# odometer        0
# title_status    0
# transmission    0
# drive           0
# size            0
# type            0
# paint_color     0
# state           0
# price           0
# dtype: int64

# %%
train["odometer"].describe()
# Out:
# count    2.753200e+04
# mean     1.160295e+05
# std      6.449916e+04
# min      1.000000e+00
# 25%      7.837100e+04
# 50%      1.114530e+05
# 75%      1.508562e+05
# max      2.946000e+06
# Name: odometer, dtype: float64

# %%
# priceの修正
train["price"]=train["price"].apply(lambda x:math.log10(x))
train
# Out:
#           id         region  year manufacturer  condition    cylinders fuel  \
# 0          0      nashville  1949          bmw  excellent  6 cylinders  gas
# 1          1  state college  2013       toyota       fair  8 cylinders  gas
# 2          2        wichita  1998         ford       good  6 cylinders  gas
# 3          3         albany  2014         ford  excellent  4 cylinders  gas
# 4          4        redding  2005         ford  excellent  6 cylinders  gas
# ...      ...            ...   ...          ...        ...          ...  ...
# 27527  27527   williamsport  2008         ford       good  6 cylinders  gas
# 27528  27528          tulsa  2007         ford  excellent  8 cylinders  gas
# 27529  27529      rochester  2019         jeep   like new  6 cylinders  gas
# 27530  27530      rochester  2007         jeep  excellent  6 cylinders  gas
# 27531  27531  orange county  2009    chevrolet  excellent  8 cylinders  gas
#
#        odometer title_status transmission drive       size         type  \
# 0      115148.0        clean       manual   rwd   mid-size  convertible
# 1      172038.0        clean    automatic   rwd  full-size        sedan
# 2      152492.0        clean    automatic   fwd  full-size          SUV
# 3      104118.0        clean       manual   fwd   mid-size          SUV
# 4      144554.0        clean       manual   fwd   mid-size        sedan
# ...         ...          ...          ...   ...        ...          ...
# 27527   26660.0        clean    automatic   rwd    compact        truck
# 27528  108072.0        clean    automatic   rwd  full-size       pickup
# 27529  139908.0        clean    automatic   4wd   mid-size          SUV
# 27530  112326.0        clean    automatic   4wd   mid-size        sedan
# 27531   91813.0      rebuilt    automatic   rwd  full-size          van
#
#       paint_color      state     price
# 0          orange  Tennessee  4.440704
# 1          silver         pa  3.674310
# 2          silver         ks  4.038660
# 3            blue         ny  4.218877
# 4             red         ca  3.712481
# ...           ...        ...       ...
# 27527       black         pa  4.508018
# 27528       black         ok  3.732394
# 27529       white         ny  4.346881
# 27530       white         ny  3.484869
# 27531       white         ca  4.318084
#
# [27532 rows x 16 columns]

# %% [markdown]
# # 特徴量の追加

# %% [markdown]
# # データの分割

# %%
train_set, test_set = train_test_split(train, test_size=0.2,random_state=0)

# %%
len(train_set)
# Out:
# 22025

# %%
len(test_set)
# Out:
# 5507

# %%
test_set
# Out:
#           id                    region  year manufacturer  condition  \
# 13009  13009                eastern CT  2004       toyota  excellent
# 3668    3668                  lawrence  2015          bmw   like new
# 22256  22256  kennewick-pasco-richland  2012         fiat   like new
# 23585  23585              rhode island  2008    chevrolet  excellent
# 25012  25012     ft myers / SW florida  2016          bmw  excellent
# ...      ...                       ...   ...          ...        ...
# 14405  14405               gainesville  2012         ford   like new
# 312      312                   boulder  2010         jeep  excellent
# 25930  25930            tampa bay area  2002       toyota   like new
# 9825    9825                 rochester  2019         ford  excellent
# 3259    3259                 sheboygan  2014        honda       fair
#
#          cylinders fuel  odometer title_status transmission drive       size  \
# 13009  8 cylinders  gas  222927.0        clean    automatic   4wd  full-size
# 3668   6 cylinders  gas  113035.0        clean    automatic   4wd  full-size
# 22256  4 cylinders  gas   71596.0        clean       manual   fwd    compact
# 23585  8 cylinders  gas  114423.0        clean    automatic   4wd  full-size
# 25012  6 cylinders  gas   59807.0        clean       manual   rwd   mid-size
# ...            ...  ...       ...          ...          ...   ...        ...
# 14405  4 cylinders  gas  108339.0        clean    automatic   fwd   mid-size
# 312    6 cylinders  gas   67562.0        clean    automatic   4wd  full-size
# 25930  6 cylinders  gas  118638.0        clean    automatic   rwd  full-size
# 9825   8 cylinders  gas   26815.0        clean    automatic   rwd  full-size
# 3259   4 cylinders  gas  135689.0        clean       manual   fwd    compact
#
#             type paint_color state     price
# 13009      truck       black    ct  3.998739
# 3668         SUV       black    ks  4.279963
# 22256  hatchback       black    wa  4.282554
# 23585      truck       black    ri  4.586182
# 25012      sedan       black    fl  4.108869
# ...          ...         ...   ...       ...
# 14405      sedan      silver    fl  4.007961
# 312          SUV       black    co  4.726849
# 25930        SUV        grey    fl  4.298329
# 9825         van       white    ny  4.244005
# 3259   hatchback         red    wi  3.983581
#
# [5507 rows x 16 columns]

# %% [markdown]
# # 学習

# %%
# !pip install --no-dependencies pycaret
# Out:
# Requirement already satisfied: pycaret in /Users/ryu/anaconda3/envs/car_price_prediction_python3_8/lib/python3.8/site-packages (3.0.4)

# %%
# !pip uninstall pycaret
# Out:
# Found existing installation: pycaret 3.0.4
# Uninstalling pycaret-3.0.4:
#   Would remove:
#     /Users/ryu/anaconda3/envs/car_price_prediction_python3_8/lib/python3.8/site-packages/pycaret-3.0.4.dist-info/*
#     /Users/ryu/anaconda3/envs/car_price_prediction_python3_8/lib/python3.8/site-packages/pycaret/*
# Proceed (Y/n)?

# %%
from pycaret.regression import *
# Out:
# ---------------------------------------------------------------------------
# ImportError                               Traceback (most recent call last)
# Cell In[26], line 1
# ----> 1 from pycaret.regression import *
#
# File ~/anaconda3/envs/car_price_prediction_python3_8/lib/python3.8/site-packages/pycaret/regression/__init__.py:1
# ----> 1 from pycaret.regression.functional import (
#       2     add_metric,
#       3     automl,
#       4     blend_models,
#       5     check_drift,
#       6     check_fairness,
#       7     compare_models,
#       8     convert_model,
#       9     create_api,
#      10     create_app,
#      11     create_docker,
#      12     create_model,
#      13     dashboard,
#      14     deep_check,
#      15     deploy_model,
#      16     eda,
#      17     ensemble_model,
#      18     evaluate_model,
#      19     finalize_model,
#      20     get_allowed_engines,
#      21     get_config,
#      22     get_current_experiment,
#      23     get_engine,
#      24     get_leaderboard,
#      25     get_logs,
#      26     get_metrics,
#      27     interpret_model,
#      28     load_experiment,
#      29     load_model,
#      30     models,
#      31     plot_model,
#      32     predict_model,
#      33     pull,
#      34     remove_metric,
#      35     save_experiment,
#      36     save_model,
#      37     set_config,
#      38     set_current_experiment,
#      39     setup,
#      40     stack_models,
#      41     tune_model,
#      42 )
#      43 from pycaret.regression.oop import RegressionExperiment
#      45 __all__ = [
#      46     "RegressionExperiment",
#      47     "setup",
#    (...)
#      86     "check_drift",
#      87 ]
#
# File ~/anaconda3/envs/car_price_prediction_python3_8/lib/python3.8/site-packages/pycaret/regression/functional.py:10
#       8 from pycaret.internal.parallel.parallel_backend import ParallelBackend
#       9 from pycaret.loggers.base_logger import BaseLogger
# ---> 10 from pycaret.regression.oop import RegressionExperiment
#      11 from pycaret.utils.constants import DATAFRAME_LIKE, SEQUENCE_LIKE, TARGET_LIKE
#      12 from pycaret.utils.generic import check_if_global_is_not_none
#
# File ~/anaconda3/envs/car_price_prediction_python3_8/lib/python3.8/site-packages/pycaret/regression/oop.py:11
#       8 from joblib.memory import Memory
#      10 from pycaret.containers.metrics.regression import get_all_metric_containers
# ---> 11 from pycaret.containers.models.regression import (
#      12     ALL_ALLOWED_ENGINES,
#      13     get_all_model_containers,
#      14     get_container_default_engines,
#      15 )
#      16 from pycaret.internal.display import CommonDisplay
#      17 from pycaret.internal.logging import get_logger
#
# File ~/anaconda3/envs/car_price_prediction_python3_8/lib/python3.8/site-packages/pycaret/containers/models/regression.py:18
#      15 from packaging import version
#      17 import pycaret.containers.base_container
# ---> 18 from pycaret.containers.models.base_model import (
#      19     ModelContainer,
#      20     leftover_parameters_to_categorical_distributions,
#      21 )
#      22 from pycaret.internal.distributions import (
#      23     Distribution,
#      24     IntUniformDistribution,
#      25     UniformDistribution,
#      26 )
#      27 from pycaret.utils._dependencies import _check_soft_dependencies
#
# File ~/anaconda3/envs/car_price_prediction_python3_8/lib/python3.8/site-packages/pycaret/containers/models/base_model.py:9
#       7 from pycaret.containers.base_container import BaseContainer
#       8 from pycaret.internal.distributions import CategoricalDistribution
# ----> 9 from pycaret.internal.pycaret_experiment.pycaret_experiment import _PyCaretExperiment
#      10 from pycaret.utils.generic import get_allowed_engines, get_logger
#      13 class ModelContainer(BaseContainer):
#
# File ~/anaconda3/envs/car_price_prediction_python3_8/lib/python3.8/site-packages/pycaret/internal/pycaret_experiment/pycaret_experiment.py:11
#       8 import pandas as pd
#      10 import pycaret.internal.patches.sklearn
# ---> 11 import pycaret.internal.patches.yellowbrick
#      12 import pycaret.internal.persistence
#      13 from pycaret.internal.logging import get_logger
#
# File ~/anaconda3/envs/car_price_prediction_python3_8/lib/python3.8/site-packages/pycaret/internal/patches/yellowbrick.py:1
# ----> 1 from yellowbrick.utils.helpers import get_model_name as get_model_name_original
#       3 from pycaret.internal.meta_estimators import get_estimator_from_meta_estimator
#       6 def is_estimator(model):
#
# File ~/anaconda3/envs/car_price_prediction_python3_8/lib/python3.8/site-packages/yellowbrick/__init__.py:39
#      37 from .anscombe import anscombe
#      38 from .datasaurus import datasaurus
# ---> 39 from .classifier import ROCAUC, ClassBalance, ClassificationScoreVisualizer
#      41 # from .classifier import crplot, rocplot
#      42 # from .regressor import peplot, residuals_plot
#      43
#    (...)
#      46 ## Set default aesthetics
#      47 ##########################################################################
#      49 set_aesthetic()  # NOTE: modifies mpl.rcParams
#
# File ~/anaconda3/envs/car_price_prediction_python3_8/lib/python3.8/site-packages/yellowbrick/classifier/__init__.py:31
#      29 from .rocauc import ROCAUC, roc_auc
#      30 from .threshold import DiscriminationThreshold, discrimination_threshold
# ---> 31 from .prcurve import PrecisionRecallCurve, PRCurve, precision_recall_curve
#      33 ## Import from target for backward compatibility and classifier association
#      34 from ..target.class_balance import ClassBalance, class_balance
#
# File ~/anaconda3/envs/car_price_prediction_python3_8/lib/python3.8/site-packages/yellowbrick/classifier/prcurve.py:24
#      21 import numpy as np
#      23 from sklearn.preprocessing import label_binarize
# ---> 24 from sklearn.multiclass import OneVsRestClassifier
#      25 from sklearn.utils.multiclass import type_of_target
#      26 from sklearn.metrics import average_precision_score
#
# File ~/anaconda3/envs/car_price_prediction_python3_8/lib/python3.8/site-packages/sklearn/multiclass.py:45
#      43 from .base import MultiOutputMixin
#      44 from .base import MetaEstimatorMixin, is_regressor
# ---> 45 from .base import _is_pairwise
#      46 from .preprocessing import LabelBinarizer
#      47 from .metrics.pairwise import euclidean_distances
#
# ImportError: cannot import name '_is_pairwise' from 'sklearn.base' (/Users/ryu/anaconda3/envs/car_price_prediction_python3_8/lib/python3.8/site-packages/sklearn/base.py)
